# %% [markdown]
# ### Question 1(a)

# %%
import string
from nltk import FreqDist

# load text and convert to lowercase and remove punctuation, and split(similar to tokenize)
input_string = open('C:\\Users\\bless\\PycharmProjects\\practicum\\emma.txt', 'r', encoding='utf-8')
input_string = input_string.read()
input_string = input_string.lower()
input_string = input_string.translate(str.maketrans('','',string.punctuation))


# define a function to get word frequencies
def get_word_freq(input_string):
    input_string_list= input_string.split()
#     print(input_string_list)

    di = []

    for i in input_string_list:
      
        if i not in di:
            di.append(i)
        
#     print(di)
    
    for i in range(0, len(di)):
        count = input_string_list.count(di[i])
        print(di[i], count)

   


def Driver():
    get_word_freq(input_string)
    
if __name__ == '__main__':
    Driver()
# Out:
# ﻿the 1
# project 84
# gutenberg 25
# ebook 10
# of 4367
# emma 723
# by 584
# jane 261
# austen 4
# this 524
# is 1234
# for 1304
# the 5274
# use 47
# anyone 5
# anywhere 16
# at 1029
# no 629
# cost 4
# and 4535
# with 1246
# almost 88
# restrictions 2
# whatsoever 2
# you 1814
# may 233
# copy 13
# it 2244
# give 160
# away 132
# or 548
# reuse 2
# under 68
# terms 29
# license 15
# included 8
# online 4
# wwwgutenbergorg 3
# title 1
# author 2
# release 2
# date 6
# august 3
# 1994 1
# etext 1
# 158 1
# posting 1
# january 5
# 21 1
# 2010 1
# last 116
# updated 2
# march 2
# 10 1
# 2018 1
# language 10
# english 9
# character 43
# set 71
# encoding 1
# utf8 1
# start 8
# produced 17
# an 464
# anonymous 2
# volunteer 3
# volume 3
# i 2598
# chapter 56
# woodhouse 249
# handsome 30
# clever 24
# rich 14
# a 3101
# comfortable 34
# home 112
# happy 116
# disposition 23
# seemed 139
# to 5202
# unite 3
# some 260
# best 79
# blessings 6
# existence 5
# had 1610
# lived 25
# ...

# %%
print(input_string_list[0:100])
# Out:
# ['\ufeffthe', 'project', 'gutenberg', 'ebook', 'of', 'emma', 'by', 'jane', 'austen', 'this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', 'you', 'may', 'copy', 'it', 'give', 'it', 'away', 'or', 'reuse', 'it', 'under', 'the', 'terms', 'of', 'the', 'project', 'gutenberg', 'license', 'included', 'with', 'this', 'ebook', 'or', 'online', 'at', 'wwwgutenbergorg', 'title', 'emma', 'author', 'jane', 'austen', 'release', 'date', 'august', '1994', 'etext', '158', 'posting', 'date', 'january', '21', '2010', 'last', 'updated', 'march', '10', '2018', 'language', 'english', 'character', 'set', 'encoding', 'utf8', 'start', 'of', 'this', 'project', 'gutenberg', 'ebook', 'emma', 'produced', 'by', 'an', 'anonymous', 'volunteer', 'emma', 'by', 'jane', 'austen', 'volume', 'i', 'chapter', 'i']

# %%
fd = FreqDist()
for word in input_string_list:
    fd[word] += 1

# %%
most_common_words = map(lambda p: str(p[0]) + " "+ str(p[1]), fd.most_common(20))
for cw in most_common_words:
    print(cw)
# Out:
# the 5274
# to 5202
# and 4535
# of 4367
# a 3101
# i 2598
# was 2367
# her 2356
# it 2244
# she 2208
# in 2182
# not 2108
# be 1970
# you 1814
# that 1715
# he 1697
# had 1610
# as 1426
# have 1307
# for 1304

# %%
import pandas as pd

row_list = []
rank = 0

for x in fd.most_common():
    word = x[0]
    count = x[1]
    rank += 1
    
    row = {'Word': word, 'Rank': rank, 'Frequency': count}
    row_list.append(row)
print(row_list[:5])
# Out:
# [{'Word': 'the', 'Rank': 1, 'Frequency': 5274}, {'Word': 'to', 'Rank': 2, 'Frequency': 5202}, {'Word': 'and', 'Rank': 3, 'Frequency': 4535}, {'Word': 'of', 'Rank': 4, 'Frequency': 4367}, {'Word': 'a', 'Rank': 5, 'Frequency': 3101}]

# %%
df = pd.DataFrame(row_list, columns = ['Word', 'Rank', 'Frequency'])

print(df.head(20))
# Out:
#     Word  Rank  Frequency
# 0    the     1       5274
# 1     to     2       5202
# 2    and     3       4535
# 3     of     4       4367
# 4      a     5       3101
# 5      i     6       2598
# 6    was     7       2367
# 7    her     8       2356
# 8     it     9       2244
# 9    she    10       2208
# 10    in    11       2182
# 11   not    12       2108
# 12    be    13       1970
# 13   you    14       1814
# 14  that    15       1715
# 15    he    16       1697
# 16   had    17       1610
# 17    as    18       1426
# 18  have    19       1307
# 19   for    20       1304

# %%
import os
current_path = 'C:\\Users\\bless\\PycharmProjects\\practicum'
df.to_csv(os.path.join(current_path, '158-0-zipflaw.csv'), index = False, encoding = 'utf-8')

df = None

csv_data = pd.read_csv(os.path.join(current_path, '158-0-zipflaw.csv'), encoding = 'utf-8')

print(csv_data.head(20))
# Out:
#     Word  Rank  Frequency
# 0    the     1       5274
# 1     to     2       5202
# 2    and     3       4535
# 3     of     4       4367
# 4      a     5       3101
# 5      i     6       2598
# 6    was     7       2367
# 7    her     8       2356
# 8     it     9       2244
# 9    she    10       2208
# 10    in    11       2182
# 11   not    12       2108
# 12    be    13       1970
# 13   you    14       1814
# 14  that    15       1715
# 15    he    16       1697
# 16   had    17       1610
# 17    as    18       1426
# 18  have    19       1307
# 19   for    20       1304

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
plt.plot(csv_data['Rank'], csv_data['Frequency'])
plt.xlabel('frequency (f)', fontweight='bold')
plt.ylabel('Rank (r)', fontweight='bold')
plt.grid()
plt.show()

# %%
plt.loglog(csv_data['Rank'], csv_data['Frequency'])
plt.xlabel('frequency (f)', fontweight='bold')
plt.ylabel('Rank (r)', fontweight='bold')
plt.grid()
plt.show()

# %%
import numpy as np

logFrequency = np.log10(csv_data['Frequency'])
logRank = np.log10(csv_data['Rank'])

coefficients = np.polyfit(logFrequency, logRank, 1)

print(coefficients)
# Out:
# [-0.78658834  3.89889803]

# %%
import scipy

def rsquared(x, y):
    slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)
    return r_value**2

print(rsquared(logFrequency, logRank))
# Out:
# 0.9664522586325738

# %% [markdown]
# ##### It does not really confirm Zipf's law
#
# ##### At the extreme ends of the plotted line, the lines tend to be flattened horizontally

# %% [markdown]
# ### Question 1(b)

# %%
import random
import string

# %%
#Define a function to generate random text
def string_gen(str_size, allowed_chars):
    return ''.join(random.choice(allowed_chars) for x in range(str_size))

chars = ('abcdef ')
text = string_gen(100000, chars)
print(text)
# Out:
# dd ffd c  eefdfafabfff f bddbaddbcbcccfafbcacbeefcfa dcab aeaaadddbbfbefaadf cabdbd  a f ccbecdbbda  d dbbbdcaebeaafd efdfedaafcfcd fbfecffeadb cecfe be cb  cd a  acecdfaabe cbceecad aca ecaedeebeed efcdbaeafcfecadbedbf  becaedfafaa fdd feceaebf fdbffacedeafaaea d abdeecaba bafbc  e  e aaa fdecba f  ceaa bbd bef fbafd cebfbedfdfacabdcacaafeaeaff   da b eedced eb ebdbaabcfc ebda acbbfed bf eaeca ccbaeafccedfbfaa  a  db dfda   ea fbbbebe eceafdfbcbfdece f bdddfaaabadadfe aefecbedaafceeececedacdefdf aeeaeeeabbcc a beab af cfdaecf ecbdfae ecfbadfadedfabfeffcee ddcbdbbebfaafecaebdeaedaedfbefbdcfdeedafdee bbdefffbadedbdcbbacbdaec bf aad cecfdf  caa aeafffeccb fda cf faafcacaacffbfacfbddafedecf e e  bddbccfef    dbeefcdfaf fabe fdbb dbcce eccbaf ceffb e fded eeaedbaafaaaeadeaaabdfdbebbffc  fcecbefcecccedbeffead  e dcbecfedce fafb a  a ecdefccdcbfdafbbc c dfef edafbafca  feccebadffdfdcddfdfcfbdffdbcbfe bbd bdecdbc aa e cdddbaa  dfadeaeb bcda cdbbd bbd ede daafbecded cddb afbca cddfbd baacaa 
# ...

# %%
#tokenize text
from nltk import word_tokenize, sent_tokenize
text = word_tokenize(str(text))

print(text)
# Out:
# ['dd', 'ffd', 'c', 'eefdfafabfff', 'f', 'bddbaddbcbcccfafbcacbeefcfa', 'dcab', 'aeaaadddbbfbefaadf', 'cabdbd', 'a', 'f', 'ccbecdbbda', 'd', 'dbbbdcaebeaafd', 'efdfedaafcfcd', 'fbfecffeadb', 'cecfe', 'be', 'cb', 'cd', 'a', 'acecdfaabe', 'cbceecad', 'aca', 'ecaedeebeed', 'efcdbaeafcfecadbedbf', 'becaedfafaa', 'fdd', 'feceaebf', 'fdbffacedeafaaea', 'd', 'abdeecaba', 'bafbc', 'e', 'e', 'aaa', 'fdecba', 'f', 'ceaa', 'bbd', 'bef', 'fbafd', 'cebfbedfdfacabdcacaafeaeaff', 'da', 'b', 'eedced', 'eb', 'ebdbaabcfc', 'ebda', 'acbbfed', 'bf', 'eaeca', 'ccbaeafccedfbfaa', 'a', 'db', 'dfda', 'ea', 'fbbbebe', 'eceafdfbcbfdece', 'f', 'bdddfaaabadadfe', 'aefecbedaafceeececedacdefdf', 'aeeaeeeabbcc', 'a', 'beab', 'af', 'cfdaecf', 'ecbdfae', 'ecfbadfadedfabfeffcee', 'ddcbdbbebfaafecaebdeaedaedfbefbdcfdeedafdee', 'bbdefffbadedbdcbbacbdaec', 'bf', 'aad', 'cecfdf', 'caa', 'aeafffeccb', 'fda', 'cf', 'faafcacaacffbfacfbddafedecf', 'e', 'e', 'bddbccfef', 'dbeefcdfaf', 'fabe', 'fdbb', 'dbcce', 'eccbaf', 'ceffb'
# ...

# %%
# determine frequency of words
fd = FreqDist()
for string in text:
    fd[string] += 1

# %%
most_common_strings = map(lambda p: str(p[0]) + " "+ str(p[1]), fd.most_common(20))
for cw in most_common_strings:
    print(cw)
# Out:
# d 306
# e 306
# c 295
# b 292
# a 278
# f 268
# fb 58
# be 55
# bc 52
# ae 51
# ca 49
# bf 47
# cb 46
# db 46
# af 46
# cf 46
# fc 46
# cd 44
# ed 44
# ba 43

# %%
# create a list/table with string, rank and frequency
row_list = []
rank = 0

for x in fd.most_common():
    string = x[0]
    count = x[1]
    rank += 1
    
    row = {'String': string, 'Rank': rank, 'Frequency': count}
    row_list.append(row)
print(row_list[:5])
# Out:
# [{'String': 'd', 'Rank': 1, 'Frequency': 306}, {'String': 'e', 'Rank': 2, 'Frequency': 306}, {'String': 'c', 'Rank': 3, 'Frequency': 295}, {'String': 'b', 'Rank': 4, 'Frequency': 292}, {'String': 'a', 'Rank': 5, 'Frequency': 278}]

# %%
# create a new table/dataframe
df_strings = pd.DataFrame(row_list, columns = ['String', 'Rank', 'Frequency'])

print(df_strings.head(20))
# Out:
#    String  Rank  Frequency
# 0       d     1        306
# 1       e     2        306
# 2       c     3        295
# 3       b     4        292
# 4       a     5        278
# 5       f     6        268
# 6      fb     7         58
# 7      be     8         55
# 8      bc     9         52
# 9      ae    10         51
# 10     ca    11         49
# 11     bf    12         47
# 12     cb    13         46
# 13     db    14         46
# 14     af    15         46
# 15     cf    16         46
# 16     fc    17         46
# 17     cd    18         44
# 18     ed    19         44
# 19     ba    20         43

# %%
# store dataframe as a csv file
df_strings.to_csv(os.path.join(current_path, 'Strings-zipflaw.csv'), index = False, encoding = 'utf-8')

df = None

strings_data = pd.read_csv(os.path.join(current_path, 'Strings-zipflaw.csv'), encoding = 'utf-8')

print(strings_data.head(20))
# Out:
#    String  Rank  Frequency
# 0       d     1        306
# 1       e     2        306
# 2       c     3        295
# 3       b     4        292
# 4       a     5        278
# 5       f     6        268
# 6      fb     7         58
# 7      be     8         55
# 8      bc     9         52
# 9      ae    10         51
# 10     ca    11         49
# 11     bf    12         47
# 12     cb    13         46
# 13     db    14         46
# 14     af    15         46
# 15     cf    16         46
# 16     fc    17         46
# 17     cd    18         44
# 18     ed    19         44
# 19     ba    20         43

# %%
# plot the raw data

plt.plot(strings_data['Rank'], strings_data['Frequency'])
plt.xlabel('frequency (f)', fontweight='bold')
plt.ylabel('Rank (r)', fontweight='bold')
plt.grid()
plt.show()

# %% [markdown]
# ### Question 1 (c)

# %%
# log transformation and print out coefficients
logFrequency_r = np.log10(strings_data['Frequency'])
logRank_r = np.log10(strings_data['Rank'])

random_coefficients = np.polyfit(logFrequency_r, logRank_r, 1)

print("The regression coefficients for the random text : {}".format(random_coefficients))
print("The regression coefficients for the selected text : {}".format(coefficients))
# Out:
# The regression coefficients for the random text : [-1.70093189  3.51870038]
# The regression coefficients for the selected text : [-0.78658834  3.89889803]

# %%
# plot log of rank and frequency
plt.plot(logRank_r, logFrequency_r)
plt.xlabel('frequency (f)', fontweight='bold')
plt.ylabel('Rank (r)', fontweight='bold')
plt.grid()
plt.show()

# %%
# print out r^2 values
print("The r^2 value of the selected text: {} " .format(rsquared(logFrequency, logRank)))
print("The r^2 value of the random text: {} " .format(rsquared(logFrequency_r, logRank_r)))
# Out:
# The r^2 value of the selected text: 0.9664522586325738
# The r^2 value of the random text: 0.5731033612642548

# %% [markdown]
# ### Question 2

# %%
from nltk.corpus import ppattach
import random

ppattach.attachments('training')


inst = ppattach.attachments('training')[:]
# (inst.noun1, inst.prep, inst.noun2)


# Select only the instances where inst.attachment is N:
nattach = [inst for inst in ppattach.attachments('training') if inst.attachment == 'N']

# %%
print(ppattach.attachments('training'))
# Out:
# [PPAttachment(sent='0', verb='join', noun1='board', prep='as', noun2='director', attachment='V'), PPAttachment(sent='1', verb='is', noun1='chairman', prep='of', noun2='N.V.', attachment='N'), ...]

# %%
print(inst[3].prep)
# Out:
# of

# %%
print(nattach[3].prep)
print(nattach[3].noun1)
print(nattach[3].noun2)
# Out:
# in
# asbestos
# products

# %%
prep_df = pd.DataFrame(columns=['sent', 'noun1', 'prep', 'noun2'])
for i in range(len(nattach)):
    prep_df=prep_df.append({
        'sent': nattach[i].sent,
        'noun1': nattach[i].noun1,
        'prep': nattach[i].prep,
        'noun2': nattach[i].noun2
    }, ignore_index=True)

# %%
prep_df.head(10)
# Out:
#   sent       noun1   prep         noun2
# 0    1    chairman     of          N.V.
# 1    2    director     of  conglomerate
# 2    3  percentage     of        deaths
# 3    9    asbestos     in      products
# 4   12        team     of   researchers
# 5   13       paper    for       filters
# 6   16       three   with        cancer
# 7   18     finding  among         those
# 8   22         one     of       nations
# 9   22    standard     of    regulation

# %%
 
def get_prep(n1, n2):
    n1=input('noun1: ')
    n2=input('noun2: ')
    global prep_df
    
    
    return prep_df[(prep_df['noun1']==n1) & (prep_df['noun2']==n2)].prep
   
        
        

       
    
          
    
   

get_prep(' ', ' ')
# Out:
# noun1: concerns
# noun2: outlook
# 10860    about
# Name: prep, dtype: object

# %%
def get_features(n1, n2):
    feature = {
        'noun1': n1,
        'noun2': n2        
    }
    return feature

# %%
featuresets = [(get_features(nattach.noun1, nattach.noun2), nattach.prep) for nattach in nattach]
size = int(len(featuresets) * 0.80)
train_set, test_set = featuresets[size:], featuresets[:size]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(get_features('concerns', 'outlook'))
# Out:
# 'about'

# %%
print('Accuracy of Classifier: %4.2f' % nltk.classify.accuracy(classifier, test_set))
# Out:
# Accuracy of Classifier: 0.50

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#                    noun2 = 'million'          of : to     =     16.5 : 1.0
#                    noun1 = 'decline'          in : of     =     14.4 : 1.0
#                    noun1 = 'increase'         in : of     =     10.9 : 1.0
#                    noun1 = 'approval'        for : of     =      9.2 : 1.0
#                    noun1 = '%'                of : becaus =      8.2 : 1.0

# %% [markdown]
# ### Question 3

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\bless\PycharmProjects\practicum\Practicum_5\1976-2018-senate.tab', delimiter='\t')

# %%
df.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic     office  \
# 0  1976  Arizona       AZ           4         86        61  US Senate
# 1  1976  Arizona       AZ           4         86        61  US Senate
# 2  1976  Arizona       AZ           4         86        61  US Senate
# 3  1976  Arizona       AZ           4         86        61  US Senate
# 4  1976  Arizona       AZ           4         86        61  US Senate
#
#     district stage  special            candidate        party  writein   mode  \
# 0  statewide   gen    False          Sam Steiger   republican    False  total
# 1  statewide   gen    False  Wm. Mathews Feighan  independent    False  total
# 2  statewide   gen    False     Dennis DeConcini     democrat    False  total
# 3  statewide   gen    False        Allan Norwitz  libertarian    False  total
# 4  statewide   gen    False            Bob Field  independent    False  total
#
#    candidatevotes  totalvotes  unofficial     version
# ...

# %%
df.tail()
# Out:
#       year      state state_po  state_fips  state_cen  state_ic     office  \
# 3416  2018  Wisconsin       WI          55         35        25  US Senate
# 3417  2018    Wyoming       WY          56         83        68  US Senate
# 3418  2018    Wyoming       WY          56         83        68  US Senate
# 3419  2018    Wyoming       WY          56         83        68  US Senate
# 3420  2018    Wyoming       WY          56         83        68  US Senate
#
#        district stage  special       candidate        party  writein   mode  \
# 3416  statewide   gen    False             NaN          NaN     True  total
# 3417  statewide   gen    False   John Barrasso   republican    False  total
# 3418  statewide   gen    False    Gary Trauner     democrat    False  total
# 3419  statewide   gen    False  Joseph Porambo  libertarian    False  total
# 3420  statewide   gen    False             NaN          NaN     True  total
#
#       candidatevotes  totalvotes  unofficial     version
# ...

# %%
df.head(20)
# Out:
#     year        state state_po  state_fips  state_cen  state_ic     office  \
# 0   1976      Arizona       AZ           4         86        61  US Senate
# 1   1976      Arizona       AZ           4         86        61  US Senate
# 2   1976      Arizona       AZ           4         86        61  US Senate
# 3   1976      Arizona       AZ           4         86        61  US Senate
# 4   1976      Arizona       AZ           4         86        61  US Senate
# 5   1976   California       CA           6         93        71  US Senate
# 6   1976   California       CA           6         93        71  US Senate
# 7   1976   California       CA           6         93        71  US Senate
# 8   1976   California       CA           6         93        71  US Senate
# 9   1976   California       CA           6         93        71  US Senate
# 10  1976  Connecticut       CT           9         16         1  US Senate
# ...

# %%
df['percentage_votes'] = 100 * (df['candidatevotes']/ df['totalvotes'])

# %%
df.head(10)
# Out:
#    year       state state_po  state_fips  state_cen  state_ic     office  \
# 0  1976     Arizona       AZ           4         86        61  US Senate
# 1  1976     Arizona       AZ           4         86        61  US Senate
# 2  1976     Arizona       AZ           4         86        61  US Senate
# 3  1976     Arizona       AZ           4         86        61  US Senate
# 4  1976     Arizona       AZ           4         86        61  US Senate
# 5  1976  California       CA           6         93        71  US Senate
# 6  1976  California       CA           6         93        71  US Senate
# 7  1976  California       CA           6         93        71  US Senate
# 8  1976  California       CA           6         93        71  US Senate
# 9  1976  California       CA           6         93        71  US Senate
#
#     district stage  special             candidate                 party  \
# 0  statewide   gen    False           Sam Steiger            republican
# ...

# %%
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic     office  \
# 0  1976  Arizona       AZ           4         86        61  US Senate
# 1  1976  Arizona       AZ           4         86        61  US Senate
# 2  1976  Arizona       AZ           4         86        61  US Senate
# 3  1976  Arizona       AZ           4         86        61  US Senate
# 4  1976  Arizona       AZ           4         86        61  US Senate
#
#     district stage  special            candidate        party  writein   mode  \
# 0  statewide   gen    False          Sam Steiger   republican    False  total
# 1  statewide   gen    False  Wm. Mathews Feighan  independent    False  total
# 2  statewide   gen    False     Dennis DeConcini     democrat    False  total
# 3  statewide   gen    False        Allan Norwitz  libertarian    False  total
# 4  statewide   gen    False            Bob Field  independent    False  total
#
#    candidatevotes  totalvotes  unofficial     version  percentage_votes
# ...

# %%
df_r = df[['state_po', 'percentage_votes', 'party']]

# %%
df_r.head()
# Out:
#   state_po  percentage_votes        party
# 0       AZ         43.339404   republican
# 1       AZ          0.211141  independent
# 2       AZ         54.010874     democrat
# 3       AZ          0.986225  libertarian
# 4       AZ          1.452355  independent

# %%
df_r.isnull().sum()
# Out:
# state_po              0
# percentage_votes      0
# party               563
# dtype: int64

# %%
df_r['party'] = df['party'].replace(np.NaN, 'none')
# Out:
# <ipython-input-485-75ae18f7706b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_r['party'] = df['party'].replace(np.NaN, 'none')

# %%
df_r.isnull().sum()
# Out:
# state_po            0
# percentage_votes    0
# party               0
# dtype: int64

# %%
from sklearn import preprocessing 
le = LabelEncoder()

state = df_r['state_po']
party = df_r['party']
pct_votes = df_r['percentage_votes']
party_coded = le.fit_transform(party)
state_coded = le.fit_transform(state)

# %%
def transform(tup, di):
    di = dict(tup)   
    return di

# %%
partycode = zip(party_coded, party)
party_dict = {}

party_dict = transform(partycode, party_dict)

print(party_dict[35])
# Out:
# democrat

# %%
statecode = zip(state_coded, state)
state_dict = {}

state_dict = transform(statecode, state_dict)

print(state_dict[2])
# Out:
# AR

# %%
features = zip(state_coded, pct_votes)
features = pd.DataFrame(features, columns=['state', 'percent_votes'])
features.head()
# Out:
#    state  percent_votes
# 0      3      43.339404
# 1      3       0.211141
# 2      3      54.010874
# 3      3       0.986225
# 4      3       1.452355

# %%
X = features
y = party_dict

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
gnb = GaussianNB()
model_gnb = gnb.fit(X_train, y_train)
y_pred = model_gnb.predict(X_test)

accuracy = model_gnb.score(X_test, y_test) * 100
print('Accuracy of model: {:.2f}%'.format(accuracy))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-539-eb356ed8d192> in <module>
#       2 from sklearn.naive_bayes import GaussianNB
#       3
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#       5 gnb = GaussianNB()
#       6 model_gnb = gnb.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2125         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2126
# -> 2127     arrays = indexable(*arrays)
#    2128
#    2129     n_samples = _num_samples(arrays[0])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     291     """
#     292     result = [_make_indexable(X) for X in iterables]
# --> 293     check_consistent_length(*result)
#     294     return result
#     295
#
# ...

# %%
X = (state,  percent_votes)
# prediction = model_gnb.predict(X1)

def get_predictions(state, percent_votes):
    X = (state,  percent_votes)
    percent_votes =features['percent_votes']
    return model_gnb.predict(X)

get_predictions(3, 63)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-543-3be4e502ace0> in <module>
# ----> 1 X = (state,  percent_votes)
#       2 # prediction = model_gnb.predict(X1)
#       3
#       4 def get_predictions(state, percent_votes):
#       5     X = (state,  percent_votes)
#
# NameError: name 'percent_votes' is not defined

# %% [markdown]
# ### Question 4

# %%
import bnlearn as bn

model = bn.import_DAG('C:\\Users\\bless\\PycharmProjects\\practicum\\Practicum_5\\sachs_simple.bif')

bn.print_CPD(model)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-506-24447b787306> in <module>
# ----> 1 import bnlearn as bn
#       2
#       3 mydf = bn.import_DAG('C:\\Users\\bless\\PycharmProjects\\practicum\\Practicum_5\\sachs_simple.bif')
#       4
#       5 mydf = mydf.read()
#
# ModuleNotFoundError: No module named 'bnlearn'

# %%
# pplot from the model

G = bn.plot(model)
# Out:
# 'network unknown {\n}\nvariable Akt {\n  type discrete [ 3 ] { LOW, AVG, HIGH };\n}\nvariable Erk {\n  type discrete [ 3 ] { LOW, AVG, HIGH };\n}\nvariable Jnk {\n  type discrete [ 3 ] { LOW, AVG, HIGH };\n}\nvariable Mek {\n  type discrete [ 3 ] { LOW, AVG, HIGH };\n}\nvariable P38 {\n  type discrete [ 3 ] { LOW, AVG, HIGH };\n}\nvariable PKA {\n  type discrete [ 3 ] { LOW, AVG, HIGH };\n}\nvariable PKC {\n  type discrete [ 3 ] { LOW, AVG, HIGH };\n}\nvariable Raf {\n  type discrete [ 3 ] { LOW, AVG, HIGH };\n}\nprobability ( Akt | Erk, PKA ) {\n  (LOW, LOW) 0.6721176592, 0.3277794919, 0.0001028489;\n  (AVG, LOW) 0.3349505840, 0.6648697215, 0.0001796945;\n  (HIGH, LOW) 7.682262e-05, 1.183068e-01, 8.816163e-01;\n  (LOW, AVG) 0.62038586, 0.37950262, 0.00011152;\n  (AVG, AVG) 0.8214081840, 0.1782019687, 0.0003898473;\n  (HIGH, AVG) 0.177105936, 0.813732581, 0.009161483;\n  (LOW, HIGH) 0.9750859107, 0.0240549828, 0.0008591065;\n  (AVG, HIGH) 9.483619e-01, 5.154733e-02, 9.075234e-05;\n  
# ...

# %%
inf = bn.inference.fit(model, variables=['PKA'], evidence={'Mek':0, 'Erk':0, 'Akt':2})

# %%
# sampling 
df = bn.sampling(model, n=1000)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-398-d0e0fba4120a> in <module>
#       1 import math
# ----> 2 from math import stats
#       3
#       4 probability ( Akt | Erk, PKA )
#
# ImportError: cannot import name 'stats' from 'math' (unknown location)

# %%
df_sl = bn.structure_learning.fit(df, methodtype='hc', scoretype='bic')

# %%
# plot based on structure learning of sample data

bn.plot(df_sl, pos=G['pos'])

# %%
# compare networks
bn.compare_networkds(model, df_sl, pos=G['pos'])
